# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
df = pd.read_csv("amz_uk_price_prediction_dataset.csv")

# %%
df
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %% [markdown]
# **Part 1: Analyzing Best-Seller Trends Across Product Categories**
#
# Objective: Understand the relationship between product categories and their best-seller status.
#
# 1. Crosstab Analysis:
#
# - Create a crosstab between the product category and the isBestSeller status.
# - Are there categories where being a best-seller is more prevalent?
# Hint: one option is to calculate the proportion of best-sellers for each category and then sort the categories based on this proportion in descending order.
#
# 2. Statistical Tests:
# - Conduct a Chi-square test to determine if the best-seller distribution is independent of the product category.
# - Compute Cramér's V to understand the strength of association between best-seller status and category.
#
# 3. Visualizations:
# - Visualize the relationship between product categories and the best-seller status using a stacked bar chart.

# %%
# 1a) Create a crosstab between the product category and the isBestSeller status:
crosstab_result = pd.crosstab(df['category'], df['isBestSeller'])
crosstab_result
# Out:
# isBestSeller                    False  True
# category
# 3D Printers                       247      1
# 3D Printing & Scanning           4065      2
# Abrasive & Finishing Products     245      5
# Action Cameras                   1696      1
# Adapters                          251      3
# ...                               ...    ...
# Wind Instruments                  243      7
# Window Treatments                 234      5
# Women                           17559    213
# Women's Sports & Outdoor Shoes   1939     20
# eBook Readers & Accessories       246      0
#
# [296 rows x 2 columns]

# %% [markdown]
# Answer 1b) Being a bestseller is most prevalent in the categories Grocery and Health & Personal Care.

# %%
# 2a) Conduct a Chi-square test to determine if the best-seller distribution is independent of the product category.
from scipy.stats import chi2_contingency

# Chi-square test for 'MSZoning' and 'SaleCondition'
chi2_statistic, chi2_p_value, _, _ = chi2_contingency(crosstab_result)

chi2_statistic, chi2_p_value
# (36540.20270061387, 0.0)

# direct interpretation of the value of 0 - assuming that this assumption is true, 
# => the prob of observing our data is basically zero! chi 2 value refers to probability of obersing the given data
# below conclusion from that interpretation
# Out:
# (36540.20270061387, 0.0)

# %% [markdown]
# Answer 2a) The null hypothesis of the Chi-square test is that the two categorical variables are independent. Given the p-value of 0 (!), we reject the null hypothesis. This implies that there's a significant association between best-seller distribution and product category in the dataset.

# %%
# 2b) Compute Cramér's V to understand the strength of association between best-seller status and category.
from scipy.stats.contingency import association

# Computing the association between variables in 'crosstab_result' using the "cramer" method!
association(crosstab_result, method="cramer")
# Out:
# 0.1222829439760564

# %% [markdown]
# Answer 2b) The Cramér's V value of 0.122 suggests a weak association between the two variables. Though statistically significant, the strength of this relationship is not very strong in practical terms.

# %%
# 3) Visualize the relationship between product categories and the best-seller status using a stacked bar chart.
crosstab_result.plot(kind="bar", stacked=True)
plt.show()

# %%
# Better solution to show the proportion! - Adding proportion column 
crosstab_result["proportion"]= crosstab_result[True]/(crosstab_result[False]+crosstab_result[True])*100
crosstab_result
# Out:
# isBestSeller                    False  True  proportion
# category
# 3D Printers                       247     1    0.403226
# 3D Printing & Scanning           4065     2    0.049176
# Abrasive & Finishing Products     245     5    2.000000
# Action Cameras                   1696     1    0.058928
# Adapters                          251     3    1.181102
# ...                               ...   ...         ...
# Wind Instruments                  243     7    2.800000
# Window Treatments                 234     5    2.092050
# Women                           17559   213    1.198515
# Women's Sports & Outdoor Shoes   1939    20    1.020929
# eBook Readers & Accessories       246     0    0.000000
#
# [296 rows x 3 columns]

# %%
# Graph based on added proportion column
crosstab_result["proportion"].sort_values(ascending = False).head().plot(kind="bar")
plt.show()

# %% [markdown]
# **Part 2: Exploring Product Prices and Ratings Across Categories and Brands**
#
# **Objective: Investigate how different product categories influence product prices.**
#
# **0. Preliminary Step: Remove outliers in product prices.**
#
# For this purpose, we can use the IQR (Interquartile Range) method. Products priced below the first quartile minus 1.5 times the IQR or above the third quartile plus 1.5 times the IQR will be considered outliers and removed from the dataset. The next steps will be done with the dataframe without outliers.
# Hint: you can check the last Check For Understanding at the end of the lesson EDA Bivariate Analysis for a hint on how to do this.
#
# **1. Violin Plots:**
# - Use a violin plot to visualize the distribution of price across different product categories. Filter out the top 20 categories based on count for better visualization.
# - Which product category tends to have the highest median price? Don't filter here by top categories.
#
# **2. Bar Charts:**
# - Create a bar chart comparing the average price of products for the top 10 product categories (based on count).
# - Which product category commands the highest average price? Don't filter here by top categories.
#
# **3. Box Plots:**
# - Visualize the distribution of product ratings based on their category using side-by-side box plots. Filter out the top 10 categories based on count for better visualization.
# - Which category tends to receive the highest median rating from customers? Don't filter here by top categories.

# %%
# 0. Preliminary Step: Remove outliers in product prices.

def tukeys_test_outliers(data): 
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    
    # Define bounds for the outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify the outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    
    return outliers

# %%
data_series = df['price']  # replace 'ColumnName' with your specific column
outliers = tukeys_test_outliers(data_series)
print(outliers)
# 327.688 out of 2.443.651 are outliers! #only for normALLY DISTRIBUTED
# Out:
# 10         139.00
# 19         164.99
# 25         149.99
# 28         289.00
# 31         199.99
#             ...
# 2443619    166.99
# 2443627    152.58
# 2443638    108.77
# 2443641    166.99
# 2443643    158.99
# Name: price, Length: 327688, dtype: float64

# %%
df
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
# Remove outliers below 1.5 and above 3.5 IQR
Q1 = df["price"].quantile(0.25)
Q3 = df["price"].quantile(0.75)
IQR = Q3 - Q1
    
# Define bounds for the outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
    
# Identify the outliers
clean_df = df[(df["price"] > lower_bound) & (df["price"] < upper_bound)]
clean_df # use this df starting from now! 2115963 (2.443.651-327.688), so looks right
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
# P2/1. Violin Plots: Use a violin plot to visualize the distribution of price across different product categories. 
sns.violinplot(data=clean_df, x='category', y='price')
plt.show()

# %%
# Filter out the top 20 categories based on count for better visualization. 

# Get the top 20 categories by count
top20_cat = clean_df['category'].value_counts().nlargest(20).index
# Filter the dataframe
filtered_df = clean_df[clean_df['category'].isin(top20_cat)]
# Plot the violin plot
sns.violinplot(data=filtered_df, x='category', y='price', palette="coolwarm")
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()
# Out:
# C:\Users\merkm\AppData\Local\Temp\ipykernel_7996\1354880034.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=filtered_df, x='category', y='price', palette="coolwarm")

# %%
# Which product category tends to have the highest median price? Don't filter here by top categories.
top_median_prices = clean_df.groupby('category')['price'].median().sort_values(ascending=False)
print(top_median_prices)
# Out:
# category
# Desktop PCs              74.00
# Boxing Shoes             69.79
# Tablets                  69.00
# Graphics Cards           68.54
# Motherboards             67.92
#                          ...
# Adapters                  7.05
# Make-up                   7.00
# Signs & Plaques           6.99
# Arts & Crafts             5.99
# Office Paper Products     4.37
# Name: price, Length: 296, dtype: float64

# %% [markdown]
# Answer 1a) Desktop PCs are the category with the highest median price of 74.00 $.

# %%
# Part II / 2. Bar Charts: # Create a bar chart comparing the average price of products for the top 10 product categories (based on count).

# Get the top 10 categories by count
top10_cat = clean_df['category'].value_counts().nlargest(10).index
# Filter the dataframe
top10_df = clean_df[clean_df['category'].isin(top10_cat)]
sns.barplot(data=top10_df, x='category', y='price', palette="coolwarm")
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\Users\merkm\AppData\Local\Temp\ipykernel_7996\2452987415.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top10_df, x='category', y='price', palette="coolwarm")

# %%
# Which product category commands the highest average price? Don't filter here by top categories.
top_median_prices = clean_df.groupby('category')['price'].mean().sort_values(ascending=False)
print(top_median_prices)
# Answer: Its Motherboards with a price of 68.772432 $
# Out:
# category
# Motherboards             68.772432
# Boxing Shoes             67.417803
# Desktop PCs              66.915562
# Tablets                  66.552971
# Graphics Cards           65.103509
#                            ...
# Bedding Accessories       8.835220
# Adapters                  8.750197
# Signs & Plaques           8.210513
# Arts & Crafts             8.006540
# Office Paper Products     6.876369
# Name: price, Length: 296, dtype: float64

# %%
# Part II / 3. Box Plots:
# Visualize the distribution of product ratings based on their category using side-by-side box plots. 
# Filter out the top 10 categories based on count for better visualization.
top10_cat = clean_df['category'].value_counts().nlargest(10).index
# Filter the dataframe
top10_df = clean_df[clean_df['category'].isin(top10_cat)] 
sns.boxplot(data=top10_df, x='category', y='stars', palette="coolwarm")
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\Users\merkm\AppData\Local\Temp\ipykernel_7996\4119254045.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=top10_df, x='category', y='stars', palette="coolwarm")

# %%
# Now evrything without the 0 stars ratings 
top10_cat = clean_df['category'].value_counts().nlargest(10).index

# Filter the dataframe to include only top 10 categories and exclude 0-star ratings
top10_df = clean_df[(clean_df['category'].isin(top10_cat)) & (clean_df['stars'] > 0)]

# Create the box plot
sns.boxplot(data=top10_df, x='category', y='stars', palette="coolwarm")
plt.xticks(rotation=90) 
plt.show()
# Out:
# C:\Users\merkm\AppData\Local\Temp\ipykernel_7996\1327999004.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=top10_df, x='category', y='stars', palette="coolwarm")

# %%
# Which category tends to receive the highest median rating from customers? Don't filter here by top categories.
top_median_rating = clean_df.groupby('category')['stars'].median().sort_values(ascending=False)
print(top_median_rating)
# Computer Memory with a rating of 4.7
# Out:
# category
# Computer Memory                 4.7
# Building & Construction Toys    4.6
# Office Paper Products           4.6
# Luxury Food & Drink             4.6
# Kids' Play Figures              4.6
#                                ...
# Hockey Shoes                    0.0
# Hi-Fi Receivers & Separates     0.0
# Handmade Kitchen & Dining       0.0
# Handmade Jewellery              0.0
# eBook Readers & Accessories     0.0
# Name: stars, Length: 296, dtype: float64

# %% [markdown]
# **Part 3: Investigating the Interplay Between Product Prices and Ratings**
#
# **Objective: Analyze how product ratings (stars) correlate with product prices.**
#
# **1. Correlation Coefficients:**
# - Calculate the correlation coefficient between price and stars.
# - Is there a significant correlation between product price and its rating?
#
# **2. Visualizations:**
# - Use a scatter plot to visualize the relationship between product rating and price. What patterns can you observe?
# - Use a correlation heatmap to visualize correlations between all numerical variables.
# - Examine if product prices typically follow a normal distribution using a QQ plot.

# %%
# Part III | 1. Correlation Coefficients:
# Calculate the correlation coefficient between price and stars. Is there a significant correlation between product price and its rating?
correlation = clean_df['price'].corr(clean_df['stars'])
correlation
# Answer: yes, there is a weak negative linear relationship of -0.0776729987818137, meaning as price decreases, the ratings decrease as well?
# Out:
# -0.0776729987818137

# %%
# Without zero stars
stars_df = df[df['stars'] > 0]
correlation = stars_df['price'].corr(stars_df['stars'])
correlation
# still super weak negative correlation -0.00491182300075293
# Out:
# -0.00491182300075293

# %%
# Part III | 2. Visualizations:
# Use a scatter plot to visualize the relationship between product rating and price. What patterns can you observe?
sns.scatterplot(data=clean_df, x='stars', y='price')
plt.show()
# Extremely high (outlier) prices have 0 star reviews

# %%
# Same without 0 stars
sns.scatterplot(data=stars_df, x='stars', y='price')
plt.show()

# %%
# First limit dataset to only numerical variables!
df_numerical = clean_df.select_dtypes(include=['number'])

# Use a correlation heatmap to visualize correlations between all numerical variables.
correlation_matrix = df_numerical.corr()

# Setting up the matplotlib figure with an appropriate size
plt.figure(figsize=(18, 15))

# Drawing the heatmap for the numerical columns
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap for All Numerical Variables")
plt.show()
# very weak correlation between all numerical variables

# %%
# Examine if product prices typically follow a normal distribution using a QQ plot.

import statsmodels.api as sm

# Generating a Q-Q plot for 'price' to check if its distribution follows a normal distribution
sm.qqplot(clean_df['price'], line='s');
plt.show()
# product price clearly does not follow a normal distribution!
